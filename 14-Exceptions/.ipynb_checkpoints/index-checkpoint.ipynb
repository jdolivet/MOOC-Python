# %% [markdown]
# # Les exceptions

# %% [markdown]
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=sTZeuRdptc0
# " target="_blank"><img src="http://img.youtube.com/vi/sTZeuRdptc0/0.jpg"
# alt="Vidéo du cours" width="240" height="180" border="10" /></a>

# %% [markdown]
# * ## [Try...else...finally](Try-finally.ipynb)
