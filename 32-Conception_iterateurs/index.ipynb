# %% [markdown]
# # Conception d'itérateurs

# %% [markdown]
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=dcSghvrb4ac
# " target="_blank"><img src="http://img.youtube.com/vi/dcSghvrb4ac/0.jpg"
# alt="Vidéo du cours" width="240" height="180" border="10" /></a>

# %% [markdown]
# * ## [Implémenter un itérateur de permutations](Permutations.ipynb)
